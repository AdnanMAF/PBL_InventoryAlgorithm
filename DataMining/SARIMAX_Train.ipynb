# %% [markdown]
# # SARIMAX Modeling for All Families
#
# This notebook performs the following steps:
#
# 1. **Import necessary libraries.**
# 2. **Configure file paths and parameters.**
# 3. **Read `train.csv`** and identify unique product families.
# 4. **Loop through each family** to:
#    - Aggregate daily sales and promotions across all stores.
#    - Split data into training and test sets (last 28 days as test).
#    - Use `pmdarima.auto_arima` to find best `(p,d,q)(P,D,Q,m)` parameters.
#    - Fit a SARIMAX model (log‐transformed sales as endog, promotions as exog).
#    - Save each fitted model to the `Models/` folder.
#    - Forecast the last 14 days and compute performance metrics: RMSE, MAE, R².
# 5. **Save performance metrics** for all families into `performance_results.csv`.
#
# > **Note:**
# > - Adjust `AUTO_ARIMA_ARGS` if your data’s frequency or seasonal assumptions differ.
# > - This notebook assumes data is daily (`freq = "D"`) with a weekly seasonality (`m=7`).
# > - Models will be saved in `Models/` and metrics saved in `performance_results.csv`.

# %%
import os
import warnings

import numpy as np
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX, SARIMAXResults
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from pmdarima import auto_arima

# Suppress warnings (optional)
warnings.filterwarnings("ignore")

# %%
# ────────────────────────────────────────────────────────────────────────────────
# 1. CONFIGURABLE PARAMETERS
# ────────────────────────────────────────────────────────────────────────────────

# File path for train.csv (relative to notebook location)
# (Adjust this path if your train.csv is in a different folder.)
TRAIN_CSV = "../Data/DM/train.csv"

# Folder to store all SARIMAX models
ALL_MODELS_DIR = "Models"
os.makedirs(ALL_MODELS_DIR, exist_ok=True)

# Number of last days to reserve for test set (forecast horizon)
N_TEST = 14

# Frequency of the time series: 'D' = daily, 'W' = weekly, 'M' = monthly, etc.
FREQ = "D"

# Arguments for auto_arima to find best (p,d,q)(P,D,Q,m)
AUTO_ARIMA_ARGS = {
    "seasonal": True,
    "m": 7,                 # Assumes a weekly seasonal pattern (7 days)
    "start_p": 0, "start_q": 0, "max_p": 5, "max_q": 5,
    "start_P": 0, "start_Q": 0, "max_P": 2, "max_Q": 2,
    "d": None, "D": None,
    "trace": False,         # Set True to see details of auto_arima
    "error_action": "ignore",
    "suppress_warnings": True,
    "stepwise": True,
    "information_criterion": "aic",
}

# %%
# ────────────────────────────────────────────────────────────────────────────────
# 2. READ TRAIN.CSV & IDENTIFY UNIQUE FAMILIES
# ────────────────────────────────────────────────────────────────────────────────

print(f"Reading file: {TRAIN_CSV}")
df_all = pd.read_csv(TRAIN_CSV, parse_dates=["date"])

# Extract unique product families
unique_families = df_all["family"].unique()
print(f"Found {len(unique_families)} unique families.")
# Out:
# Reading file: ../Data/train.csv
# Found 33 unique families.
# Found 33 unique families.

# %%
# ────────────────────────────────────────────────────────────────────────────────
# 3. LOOP THROUGH EACH FAMILY
# ────────────────────────────────────────────────────────────────────────────────

performance_list = []

for family in unique_families:
    print("===================================================")
    print(f"Processing family: {family}")

    # Filter data for this family and aggregate daily across all stores
    df_family = df_all[df_all["family"] == family].copy()
    if df_family.empty:
        print(f"  No data for family {family}, skipping.")
        continue

    # Aggregate: sum 'sales' and 'onpromotion' by date
    df_agg = (
        df_family
        .groupby("date")[["sales", "onpromotion"]]
        .sum()
        .rename(columns={"onpromotion": "onpromo"})
        .sort_index()
    )

    # Convert index to PeriodIndex (daily) and enforce a continuous date index
    df_agg.index = pd.DatetimeIndex(df_agg.index).to_period(FREQ)
    df_agg = df_agg.asfreq(FREQ)
    df_agg["sales"]   = df_agg["sales"].fillna(0).astype(float)
    df_agg["onpromo"] = df_agg["onpromo"].fillna(0).astype(float)

    # Skip if not enough data points to hold out N_TEST days
    if len(df_agg) < N_TEST + 1:
        print(f"  Only {len(df_agg)} data points for {family}, skipping.")
        continue

    # Log-transform sales (log1p) to stabilize zeros
    df_agg["y_log"] = np.log1p(df_agg["sales"])

    # Split into train/test (last N_TEST as test)
    train_df = df_agg.iloc[:-N_TEST]
    test_df  = df_agg.iloc[-N_TEST:]
    print(f"  Train length: {len(train_df)}, Test length: {len(test_df)}")

    ts_log_train = train_df["y_log"]
    exog_train   = train_df["onpromo"]
    exog_test    = test_df["onpromo"]

    # Auto-ARIMA to find optimal SARIMAX orders
    try:
        print("  Running auto_arima for parameter tuning...")
        model_auto = auto_arima(
            ts_log_train,
            exogenous=exog_train.values.reshape(-1, 1),
            **AUTO_ARIMA_ARGS
        )
        order_opt          = model_auto.order
        seasonal_order_opt = model_auto.seasonal_order
        print(f"  Found order: {order_opt}, seasonal_order: {seasonal_order_opt}")
    except Exception as e:
        print(f"  auto_arima error for {family}: {e}")
        continue

    # Fit SARIMAX on log1p(sales) with exogenous onpromo
    try:
        print("  Fitting SARIMAX model...")
        model = SARIMAX(
            ts_log_train,
            exog=exog_train,
            order=order_opt,
            seasonal_order=seasonal_order_opt,
            enforce_stationarity=False,
            enforce_invertibility=False
        )
        sarimax_fit = model.fit(disp=False)
    except Exception as e:
        print(f"  SARIMAX fit error for {family}: {e}")
        continue

    # Save the fitted model to ALL_MODELS_DIR
    safe_name = family.replace(" ", "_").replace("/", "_").replace("\\", "_")
    model_filename = f"sarimax_family_{safe_name}.pkl"
    model_path = os.path.join(ALL_MODELS_DIR, model_filename)
    try:
        sarimax_fit.save(model_path)
        print(f"  Model saved to {model_path}")
    except Exception as e:
        print(f"  Error saving model for {family}: {e}")

    # Forecast last N_TEST days (log scale), then convert back to original scale
    try:
        pred_log = sarimax_fit.get_forecast(steps=N_TEST, exog=exog_test).predicted_mean
        pred_sales = np.expm1(pred_log)
    except Exception as e:
        print(f"  Forecast error for {family}: {e}")
        continue

    # Compute performance metrics on original scale
    actual_sales = test_df["sales"].values
    rmse = np.sqrt(mean_squared_error(actual_sales, pred_sales))
    mae  = mean_absolute_error(actual_sales, pred_sales)
    r2   = r2_score(actual_sales, pred_sales)
    print(f"  Metrics for {family}: RMSE={rmse:.2f}, MAE={mae:.2f}, R²={r2:.3f}")

    performance_list.append({
        "family": family,
        "RMSE": rmse,
        "MAE": mae,
        "R2": r2
    })

# After the loop, create a DataFrame of all performance metrics
perf_df = pd.DataFrame(performance_list)
perf_df
# Out:
# ===================================================
# Processing family: AUTOMOTIVE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 4), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 4), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_AUTOMOTIVE.pkl
#   Metrics for AUTOMOTIVE: RMSE=54.01, MAE=38.84, R²=0.579
# ===================================================
# Processing family: BABY CARE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_AUTOMOTIVE.pkl
#   Metrics for AUTOMOTIVE: RMSE=54.01, MAE=38.84, R²=0.579
# ===================================================
# Processing family: BABY CARE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (2, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (2, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_BABY_CARE.pkl
#   Metrics for BABY CARE: RMSE=4.07, MAE=3.46, R²=-0.091
# ===================================================
# Processing family: BEAUTY
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_BABY_CARE.pkl
#   Metrics for BABY CARE: RMSE=4.07, MAE=3.46, R²=-0.091
# ===================================================
# Processing family: BEAUTY
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (1, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (1, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_BEAUTY.pkl
#   Metrics for BEAUTY: RMSE=86.15, MAE=69.97, R²=0.055
# ===================================================
# Processing family: BEVERAGES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_BEAUTY.pkl
#   Metrics for BEAUTY: RMSE=86.15, MAE=69.97, R²=0.055
# ===================================================
# Processing family: BEVERAGES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_BEVERAGES.pkl
#   Metrics for BEVERAGES: RMSE=62899.86, MAE=55026.01, R²=-2.442
# ===================================================
# Processing family: BOOKS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_BEVERAGES.pkl
#   Metrics for BEVERAGES: RMSE=62899.86, MAE=55026.01, R²=-2.442
# ===================================================
# Processing family: BOOKS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 1), seasonal_order: (0, 0, 0, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_BOOKS.pkl
#   Metrics for BOOKS: RMSE=2.12, MAE=1.99, R²=-4.093
# ===================================================
# Processing family: BREAD/BAKERY
#   Found order: (0, 1, 1), seasonal_order: (0, 0, 0, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_BOOKS.pkl
#   Metrics for BOOKS: RMSE=2.12, MAE=1.99, R²=-4.093
# ===================================================
# Processing family: BREAD/BAKERY
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 2), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 2), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_BREAD_BAKERY.pkl
#   Metrics for BREAD/BAKERY: RMSE=2760.09, MAE=2283.61, R²=0.521
# ===================================================
# Processing family: CELEBRATION
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_BREAD_BAKERY.pkl
#   Metrics for BREAD/BAKERY: RMSE=2760.09, MAE=2283.61, R²=0.521
# ===================================================
# Processing family: CELEBRATION
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_CELEBRATION.pkl
#   Metrics for CELEBRATION: RMSE=189.52, MAE=142.51, R²=-0.180
# ===================================================
# Processing family: CLEANING
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_CELEBRATION.pkl
#   Metrics for CELEBRATION: RMSE=189.52, MAE=142.51, R²=-0.180
# ===================================================
# Processing family: CLEANING
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (5, 1, 1), seasonal_order: (2, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (5, 1, 1), seasonal_order: (2, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_CLEANING.pkl
#   Metrics for CLEANING: RMSE=19002.60, MAE=13131.21, R²=-0.178
# ===================================================
# Processing family: DAIRY
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_CLEANING.pkl
#   Metrics for CLEANING: RMSE=19002.60, MAE=13131.21, R²=-0.178
# ===================================================
# Processing family: DAIRY
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 1), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 1), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_DAIRY.pkl
#   Metrics for DAIRY: RMSE=5781.21, MAE=4510.31, R²=0.285
# ===================================================
# Processing family: DELI
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_DAIRY.pkl
#   Metrics for DAIRY: RMSE=5781.21, MAE=4510.31, R²=0.285
# ===================================================
# Processing family: DELI
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 3), seasonal_order: (2, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 3), seasonal_order: (2, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_DELI.pkl
#   Metrics for DELI: RMSE=2315.51, MAE=1924.26, R²=0.294
# ===================================================
# Processing family: EGGS
#   Model saved to Models\sarimax_family_DELI.pkl
#   Metrics for DELI: RMSE=2315.51, MAE=1924.26, R²=0.294
# ===================================================
# Processing family: EGGS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (1, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (1, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_EGGS.pkl
#   Metrics for EGGS: RMSE=1624.66, MAE=1306.67, R²=0.489
# ===================================================
# Processing family: FROZEN FOODS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_EGGS.pkl
#   Metrics for EGGS: RMSE=1624.66, MAE=1306.67, R²=0.489
# ===================================================
# Processing family: FROZEN FOODS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (4, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (4, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_FROZEN_FOODS.pkl
#   Metrics for FROZEN FOODS: RMSE=622.49, MAE=422.27, R²=0.865
# ===================================================
# Processing family: GROCERY I
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_FROZEN_FOODS.pkl
#   Metrics for FROZEN FOODS: RMSE=622.49, MAE=422.27, R²=0.865
# ===================================================
# Processing family: GROCERY I
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (5, 1, 1), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (5, 1, 1), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_GROCERY_I.pkl
#   Metrics for GROCERY I: RMSE=45922.28, MAE=38399.21, R²=-0.459
# ===================================================
# Processing family: GROCERY II
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_GROCERY_I.pkl
#   Metrics for GROCERY I: RMSE=45922.28, MAE=38399.21, R²=-0.459
# ===================================================
# Processing family: GROCERY II
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_GROCERY_II.pkl
#   Metrics for GROCERY II: RMSE=296.61, MAE=241.83, R²=0.356
# ===================================================
# Processing family: HARDWARE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_GROCERY_II.pkl
#   Metrics for GROCERY II: RMSE=296.61, MAE=241.83, R²=0.356
# ===================================================
# Processing family: HARDWARE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_HARDWARE.pkl
#   Metrics for HARDWARE: RMSE=10.57, MAE=9.20, R²=0.499
# ===================================================
# Processing family: HOME AND KITCHEN I
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_HARDWARE.pkl
#   Metrics for HARDWARE: RMSE=10.57, MAE=9.20, R²=0.499
# ===================================================
# Processing family: HOME AND KITCHEN I
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 1), seasonal_order: (0, 0, 0, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 1), seasonal_order: (0, 0, 0, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_HOME_AND_KITCHEN_I.pkl
#   Metrics for HOME AND KITCHEN I: RMSE=962.33, MAE=821.52, R²=-10.185
# ===================================================
# Processing family: HOME AND KITCHEN II
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_HOME_AND_KITCHEN_I.pkl
#   Metrics for HOME AND KITCHEN I: RMSE=962.33, MAE=821.52, R²=-10.185
# ===================================================
# Processing family: HOME AND KITCHEN II
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_HOME_AND_KITCHEN_II.pkl
#   Metrics for HOME AND KITCHEN II: RMSE=533.69, MAE=399.19, R²=-1.680
# ===================================================
# Processing family: HOME APPLIANCES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_HOME_AND_KITCHEN_II.pkl
#   Metrics for HOME AND KITCHEN II: RMSE=533.69, MAE=399.19, R²=-1.680
# ===================================================
# Processing family: HOME APPLIANCES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_HOME_APPLIANCES.pkl
#   Metrics for HOME APPLIANCES: RMSE=9.41, MAE=8.06, R²=-1.697
# ===================================================
# Processing family: HOME CARE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_HOME_APPLIANCES.pkl
#   Metrics for HOME APPLIANCES: RMSE=9.41, MAE=8.06, R²=-1.697
# ===================================================
# Processing family: HOME CARE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 0), seasonal_order: (0, 0, 0, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 0), seasonal_order: (0, 0, 0, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_HOME_CARE.pkl
#   Metrics for HOME CARE: RMSE=11595.75, MAE=10816.96, R²=-9.751
# ===================================================
# Processing family: LADIESWEAR
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_HOME_CARE.pkl
#   Metrics for HOME CARE: RMSE=11595.75, MAE=10816.96, R²=-9.751
# ===================================================
# Processing family: LADIESWEAR
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (2, 1, 0), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (2, 1, 0), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_LADIESWEAR.pkl
#   Metrics for LADIESWEAR: RMSE=90.05, MAE=69.91, R²=0.772
# ===================================================
# Processing family: LAWN AND GARDEN
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_LADIESWEAR.pkl
#   Metrics for LADIESWEAR: RMSE=90.05, MAE=69.91, R²=0.772
# ===================================================
# Processing family: LAWN AND GARDEN
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_LAWN_AND_GARDEN.pkl
#   Metrics for LAWN AND GARDEN: RMSE=90.49, MAE=72.08, R²=0.688
# ===================================================
# Processing family: LINGERIE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_LAWN_AND_GARDEN.pkl
#   Metrics for LAWN AND GARDEN: RMSE=90.49, MAE=72.08, R²=0.688
# ===================================================
# Processing family: LINGERIE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (1, 1, 2), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (1, 1, 2), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_LINGERIE.pkl
#   Metrics for LINGERIE: RMSE=48.23, MAE=40.34, R²=0.533
# ===================================================
# Processing family: LIQUOR,WINE,BEER
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_LINGERIE.pkl
#   Metrics for LINGERIE: RMSE=48.23, MAE=40.34, R²=0.533
# ===================================================
# Processing family: LIQUOR,WINE,BEER
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (5, 1, 1), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (5, 1, 1), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_LIQUOR,WINE,BEER.pkl
#   Metrics for LIQUOR,WINE,BEER: RMSE=1486.86, MAE=1142.15, R²=0.658
# ===================================================
# Processing family: MAGAZINES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_LIQUOR,WINE,BEER.pkl
#   Metrics for LIQUOR,WINE,BEER: RMSE=1486.86, MAE=1142.15, R²=0.658
# ===================================================
# Processing family: MAGAZINES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (1, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (1, 1, 1), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_MAGAZINES.pkl
#   Metrics for MAGAZINES: RMSE=105.25, MAE=85.12, R²=-0.179
# ===================================================
# Processing family: MEATS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_MAGAZINES.pkl
#   Metrics for MAGAZINES: RMSE=105.25, MAE=85.12, R²=-0.179
# ===================================================
# Processing family: MEATS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (3, 1, 1), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (3, 1, 1), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_MEATS.pkl
#   Metrics for MEATS: RMSE=2149.99, MAE=1853.17, R²=0.688
# ===================================================
# Processing family: PERSONAL CARE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_MEATS.pkl
#   Metrics for MEATS: RMSE=2149.99, MAE=1853.17, R²=0.688
# ===================================================
# Processing family: PERSONAL CARE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (5, 1, 0), seasonal_order: (2, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (5, 1, 0), seasonal_order: (2, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_PERSONAL_CARE.pkl
#   Metrics for PERSONAL CARE: RMSE=5560.12, MAE=4170.64, R²=-1.168
# ===================================================
# Processing family: PET SUPPLIES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_PERSONAL_CARE.pkl
#   Metrics for PERSONAL CARE: RMSE=5560.12, MAE=4170.64, R²=-1.168
# ===================================================
# Processing family: PET SUPPLIES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (3, 1, 1), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (3, 1, 1), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_PET_SUPPLIES.pkl
#   Metrics for PET SUPPLIES: RMSE=92.30, MAE=67.06, R²=0.122
# ===================================================
# Processing family: PLAYERS AND ELECTRONICS
#   Model saved to Models\sarimax_family_PET_SUPPLIES.pkl
#   Metrics for PET SUPPLIES: RMSE=92.30, MAE=67.06, R²=0.122
# ===================================================
# Processing family: PLAYERS AND ELECTRONICS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (2, 1, 0), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (2, 1, 0), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_PLAYERS_AND_ELECTRONICS.pkl
#   Metrics for PLAYERS AND ELECTRONICS: RMSE=105.26, MAE=84.47, R²=0.231
# ===================================================
# Processing family: POULTRY
#   Model saved to Models\sarimax_family_PLAYERS_AND_ELECTRONICS.pkl
#   Metrics for PLAYERS AND ELECTRONICS: RMSE=105.26, MAE=84.47, R²=0.231
# ===================================================
# Processing family: POULTRY
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (1, 1, 2), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (1, 1, 2), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_POULTRY.pkl
#   Metrics for POULTRY: RMSE=2691.12, MAE=2233.33, R²=0.585
# ===================================================
# Processing family: PREPARED FOODS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_POULTRY.pkl
#   Metrics for POULTRY: RMSE=2691.12, MAE=2233.33, R²=0.585
# ===================================================
# Processing family: PREPARED FOODS
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (1, 1, 4), seasonal_order: (0, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (1, 1, 4), seasonal_order: (0, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_PREPARED_FOODS.pkl
#   Metrics for PREPARED FOODS: RMSE=500.28, MAE=447.45, R²=-0.227
# ===================================================
# Processing family: PRODUCE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_PREPARED_FOODS.pkl
#   Metrics for PREPARED FOODS: RMSE=500.28, MAE=447.45, R²=-0.227
# ===================================================
# Processing family: PRODUCE
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (4, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (4, 1, 2), seasonal_order: (1, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_PRODUCE.pkl
#   Metrics for PRODUCE: RMSE=13122.83, MAE=11137.67, R²=0.524
# ===================================================
# Processing family: SCHOOL AND OFFICE SUPPLIES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_PRODUCE.pkl
#   Metrics for PRODUCE: RMSE=13122.83, MAE=11137.67, R²=0.524
# ===================================================
# Processing family: SCHOOL AND OFFICE SUPPLIES
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (2, 1, 0), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Found order: (2, 1, 0), seasonal_order: (2, 0, 1, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_SCHOOL_AND_OFFICE_SUPPLIES.pkl
#   Metrics for SCHOOL AND OFFICE SUPPLIES: RMSE=2376.16, MAE=1872.20, R²=-1.331
# ===================================================
# Processing family: SEAFOOD
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Model saved to Models\sarimax_family_SCHOOL_AND_OFFICE_SUPPLIES.pkl
#   Metrics for SCHOOL AND OFFICE SUPPLIES: RMSE=2376.16, MAE=1872.20, R²=-1.331
# ===================================================
# Processing family: SEAFOOD
#   Train length: 1656, Test length: 28
#   Running auto_arima for parameter tuning...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Found order: (0, 1, 2), seasonal_order: (1, 0, 2, 7)
#   Fitting SARIMAX model...
#   Model saved to Models\sarimax_family_SEAFOOD.pkl
#   Metrics for SEAFOOD: RMSE=110.94, MAE=92.93, R²=0.699
#   Model saved to Models\sarimax_family_SEAFOOD.pkl
#   Metrics for SEAFOOD: RMSE=110.94, MAE=92.93, R²=0.699
#                         family          RMSE           MAE         R2
# 0                   AUTOMOTIVE     54.013620     38.838670   0.579162
# 1                    BABY CARE      4.066891      3.455096  -0.091135
# 2                       BEAUTY     86.148931     69.973589   0.054929
# 3                    BEVERAGES  62899.859675  55026.008050  -2.441777
# 4                        BOOKS      2.120236      1.994549  -4.093057
# 5                 BREAD/BAKERY   2760.089011   2283.606417   0.520756
# 6                  CELEBRATION    189.524901    142.511266  -0.180126
# 7                     CLEANING  19002.601688  13131.213320  -0.178348
# 8                        DAIRY   5781.207215   4510.309199   0.285011
# 9                         DELI   2315.506038   1924.258297   0.294238
# 10                        EGGS   1624.663276   1306.668085   0.489111
# 11                FROZEN FOODS    622.492910    422.269324   0.864996
# 12                   GROCERY I  45922.279897  38399.212548  -0.459349
# 13                  GROCERY II    296.613206    241.828932   0.356134
# 14                    HARDWARE     10.572839      9.201385   0.499098
# 15          HOME AND KITCHEN I    962.331844    821.516080 -10.184927
# 16         HOME AND KITCHEN II    533.688410    399.185882  -1.680230
# 17             HOME APPLIANCES      9.409076      8.062190  -1.696611
# 18                   HOME CARE  11595.750119  10816.964747  -9.751263
# 19                  LADIESWEAR     90.045301     69.907517   0.771731
# 20             LAWN AND GARDEN     90.491051     72.081540   0.688148
# 21                    LINGERIE     48.227469     40.344969   0.532791
# 22            LIQUOR,WINE,BEER   1486.863814   1142.152710   0.658103
# 23                   MAGAZINES    105.246428     85.116472  -0.179048
# 24                       MEATS   2149.986409   1853.168837   0.687523
# 25               PERSONAL CARE   5560.115517   4170.635523  -1.167860
# 26                PET SUPPLIES     92.303845     67.058229   0.122056
# 27     PLAYERS AND ELECTRONICS    105.262954     84.473993   0.231265
# 28                     POULTRY   2691.122720   2233.334074   0.585408
# 29              PREPARED FOODS    500.284165    447.452868  -0.226849
# 30                     PRODUCE  13122.833029  11137.674957   0.523838
# 31  SCHOOL AND OFFICE SUPPLIES   2376.158102   1872.199995  -1.330781
# 32                     SEAFOOD    110.943888     92.926967   0.699441

# %%
# ────────────────────────────────────────────────────────────────────────────────
# 4. SAVE PERFORMANCE METRICS TO CSV
# ────────────────────────────────────────────────────────────────────────────────

perf_csv_path = "performance_results.csv"
perf_df.to_csv(perf_csv_path, index=False)
print(f"Performance results saved to {perf_csv_path}") 
perf_df
# Out:
# Performance results saved to performance_results.csv
#                         family          RMSE           MAE         R2
# 0                   AUTOMOTIVE     54.013620     38.838670   0.579162
# 1                    BABY CARE      4.066891      3.455096  -0.091135
# 2                       BEAUTY     86.148931     69.973589   0.054929
# 3                    BEVERAGES  62899.859675  55026.008050  -2.441777
# 4                        BOOKS      2.120236      1.994549  -4.093057
# 5                 BREAD/BAKERY   2760.089011   2283.606417   0.520756
# 6                  CELEBRATION    189.524901    142.511266  -0.180126
# 7                     CLEANING  19002.601688  13131.213320  -0.178348
# 8                        DAIRY   5781.207215   4510.309199   0.285011
# 9                         DELI   2315.506038   1924.258297   0.294238
# 10                        EGGS   1624.663276   1306.668085   0.489111
# 11                FROZEN FOODS    622.492910    422.269324   0.864996
# 12                   GROCERY I  45922.279897  38399.212548  -0.459349
# 13                  GROCERY II    296.613206    241.828932   0.356134
# 14                    HARDWARE     10.572839      9.201385   0.499098
# 15          HOME AND KITCHEN I    962.331844    821.516080 -10.184927
# 16         HOME AND KITCHEN II    533.688410    399.185882  -1.680230
# 17             HOME APPLIANCES      9.409076      8.062190  -1.696611
# 18                   HOME CARE  11595.750119  10816.964747  -9.751263
# 19                  LADIESWEAR     90.045301     69.907517   0.771731
# 20             LAWN AND GARDEN     90.491051     72.081540   0.688148
# 21                    LINGERIE     48.227469     40.344969   0.532791
# 22            LIQUOR,WINE,BEER   1486.863814   1142.152710   0.658103
# 23                   MAGAZINES    105.246428     85.116472  -0.179048
# 24                       MEATS   2149.986409   1853.168837   0.687523
# 25               PERSONAL CARE   5560.115517   4170.635523  -1.167860
# 26                PET SUPPLIES     92.303845     67.058229   0.122056
# 27     PLAYERS AND ELECTRONICS    105.262954     84.473993   0.231265
# 28                     POULTRY   2691.122720   2233.334074   0.585408
# 29              PREPARED FOODS    500.284165    447.452868  -0.226849
# 30                     PRODUCE  13122.833029  11137.674957   0.523838
# 31  SCHOOL AND OFFICE SUPPLIES   2376.158102   1872.199995  -1.330781
# 32                     SEAFOOD    110.943888     92.926967   0.699441
