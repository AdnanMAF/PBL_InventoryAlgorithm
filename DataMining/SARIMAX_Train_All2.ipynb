# %% [markdown]
# # SARIMAX Forecasting: Train on `train.csv`, Forecast on `test.csv`
#
# **Workflow**:
# 1. Import libraries.
# 2. Configure paths & parameters.
# 3. Read `train.csv` (with `sales`) and `test.csv` (future dates, no `sales`).
# 4. Loop over each product family:
#    - Aggregate daily `sales` & `onpromotion` from `train.csv`.
#    - (Optional) Hold out last `N_VALID` days of `train.csv` for sanity‐check metrics.
#    - Log1p‐transform `sales` and scale both the transformed `sales` and `onpromotion`.
#    - Fit SARIMAX on the scaled target/exogenous series (orders selected via `auto_arima`).
#    - Save model to `Model3/`.
#    - Forecast exactly on the dates present in `test.csv` (using its scaled `onpromotion`).
# 5. (Optional) Compute RMSE/MAE/R²/MAPE on held‐out portion of `train.csv` and save to `Performance/performance_all_families.csv`.
# 6. Save all forecasts (for `test.csv`) into `forecasts_all_families.csv`.

# %% [markdown]
# ## Import all libraries and suppress warnings

# %%
import os
import warnings
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from pmdarima import auto_arima
from IPython.display import display

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Set all paths, parameters, and output directories

# %%
# 1) File paths (adjust if needed)
TRAIN_CSV = "../data/DM/train_cleaned.csv"
TEST_CSV  = "../data/DM/test.csv"

# 2) Output directories / filenames
MODEL_DIR   = os.joinpath("Models", "Model3")
PERF_DIR    = "Performance"
FORE_DIR    = "Forecasts"
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(PERF_DIR, exist_ok=True)
os.makedirs(FORE_DIR, exist_ok=True)

PERF_CSV     = os.path.join(PERF_DIR, "performance_all_families.csv")
FORECAST_CSV = os.path.join(FORE_DIR, "forecasts_all_families.csv")

# 3) Hold-out size (set to 0 to skip hold-out)
N_VALID = 14

# 4) Time-series frequency
FREQ = "D"  # daily

# 5) auto_arima arguments
AUTO_ARIMA_ARGS = {
    "seasonal": True,
    "m": 7,
    "start_p": 0, "start_q": 0, "max_p": 5, "max_q": 5,
    "start_P": 0, "start_Q": 0, "max_P": 2, "max_Q": 2,
    "d": None, "D": None,
    "trace": False,
    "error_action": "ignore",
    "suppress_warnings": True,
    "stepwise": True,
    "information_criterion": "aic"
}

# %% [markdown]
# ## CELL 3: Load train and test CSVs, list families

# %%
print("Loading train.csv and test.csv...")
df_train_all = pd.read_csv(TRAIN_CSV, parse_dates=["date"])
df_test_all  = pd.read_csv(TEST_CSV,  parse_dates=["date"])

print(f"→ train.csv: {df_train_all.shape[0]} rows")
print(f"→ test.csv:  {df_test_all.shape[0]} rows\n")

unique_families = df_train_all["family"].unique()
print(f"Found {len(unique_families)} unique families.\n")
display(unique_families)
# Out:
# Loading train.csv and test.csv...
# → train.csv: 2061758 rows
# → test.csv:  28512 rows
#
# Found 33 unique families.
# array(['BEAUTY', 'BEVERAGES', 'BREAD/BAKERY', 'CLEANING', 'DAIRY', 'DELI',
#        'EGGS', 'FROZEN FOODS', 'GROCERY I', 'GROCERY II',
#        'LAWN AND GARDEN', 'LINGERIE', 'LIQUOR,WINE,BEER', 'MEATS',
#        'PERSONAL CARE', 'POULTRY', 'PREPARED FOODS', 'AUTOMOTIVE',
#        'HARDWARE', 'SEAFOOD', 'HOME APPLIANCES', 'PRODUCE', 'CELEBRATION',
#        'HOME AND KITCHEN I', 'HOME AND KITCHEN II', 'HOME CARE',
#        'MAGAZINES', 'PET SUPPLIES', 'PLAYERS AND ELECTRONICS',
#        'LADIESWEAR', 'SCHOOL AND OFFICE SUPPLIES', 'BABY CARE', 'BOOKS'],
#       dtype=object)

# %% [markdown]
# ## CELL 4: Define helper for Augmented Dickey-Fuller stationarity test

# %%
def test_stationarity(ts, name="series"):
    result = adfuller(ts)
    print("  ─" * 30)
    print(f"  ADF Statistic ({name}): {result[0]:.5f}")
    print(f"  p-value:            {result[1]:.5f}")
    for key, val in result[4].items():
        print(f"  Critical Value ({key}): {val:.5f}")
    if result[1] < 0.05:
        print("  → The series IS stationary (reject H₀).")
    else:
        print("  → The series is NOT stationary (fail to reject H₀).")
    print("  ─" * 30)

# %% [markdown]
# ## CELL 5: Main loop – Process each family

# %%
performance_records = []
forecast_records    = []

for family in unique_families:
    print("\n" + "=" * 60)
    print(f"Processing family = '{family}'")
    
    # 4a) Filter train for this family and aggregate by date
    df_f = df_train_all[df_train_all["family"] == family].copy()
    if df_f.empty:
        print(f"  No rows for '{family}' in train.csv. Skipping.\n")
        continue

    df_f_agg = (
        df_f.groupby("date")[["sales", "onpromotion"]]
           .sum()
           .rename(columns={"onpromotion": "onpromo"})
           .sort_index()
    )

    # Convert to daily PeriodIndex and fill missing dates with zeros
    df_f_agg.index = pd.DatetimeIndex(df_f_agg.index).to_period(FREQ)
    df_f_agg = df_f_agg.asfreq(FREQ)
    df_f_agg["sales"]   = df_f_agg["sales"].fillna(0).astype(float)
    df_f_agg["onpromo"] = df_f_agg["onpromo"].fillna(0).astype(float)

    # 4b) Remove zero-sales rows
    orig_len = len(df_f_agg)
    df_f_agg = df_f_agg[df_f_agg["sales"] != 0].copy()
    print(f"  Removed {orig_len - len(df_f_agg)} zero-sales rows → {len(df_f_agg)} remaining")

    # Ensure enough data points for hold-out
    if len(df_f_agg) < (N_VALID + 1):
        print(f"  Not enough data points ({len(df_f_agg)}) for hold-out of {N_VALID}. Skipping.\n")
        continue

    # 4c) Hold out last N_VALID days
    if N_VALID > 0:
        df_valid_holdout = df_f_agg.iloc[-N_VALID:]
        df_train_series  = df_f_agg.iloc[:-N_VALID]
        print(f"  Held out last {N_VALID} days for validation.")
    else:
        df_valid_holdout = None
        df_train_series  = df_f_agg

    # 4d) Stationarity test on raw sales (before log)
    print("  Running ADF test on training 'sales' series:")
    test_stationarity(df_train_series["sales"], name="sales")

    # 4e) Log-transform the sales column
    df_train_series["y_log"] = np.log1p(df_train_series["sales"])

    # 4f) Scale the log-transformed sales
    y_log_raw    = df_train_series["y_log"].values.reshape(-1, 1)
    scaler_y     = StandardScaler()
    y_log_scaled = scaler_y.fit_transform(y_log_raw).ravel()
    df_train_series["y_scaled"] = y_log_scaled

    # 4g) Prepare and scale exogenous (onpromo)
    exog_train_raw = df_train_series["onpromo"].values.reshape(-1, 1)
    if df_valid_holdout is not None:
        exog_valid_raw = df_valid_holdout["onpromo"].values.reshape(-1, 1)

    scaler_x = StandardScaler()
    exog_train_scaled = scaler_x.fit_transform(exog_train_raw).ravel()
    exog_train = pd.Series(exog_train_scaled, index=df_train_series.index)

    if df_valid_holdout is not None:
        exog_valid_scaled = scaler_x.transform(exog_valid_raw).ravel()
        exog_valid = pd.Series(exog_valid_scaled, index=df_valid_holdout.index)
    else:
        exog_valid = None

    # 4h) Auto-arima on the scaled target with scaled exogenous
    print("  Running auto_arima for hyperparameter tuning...")
    try:
        mi = auto_arima(
            df_train_series["y_scaled"],
            exogenous=exog_train.values.reshape(-1, 1),
            **AUTO_ARIMA_ARGS
        )
        order_opt          = mi.order
        seasonal_order_opt = mi.seasonal_order
        print(f"   → Selected order = {order_opt}, seasonal_order = {seasonal_order_opt}")
    except Exception as e:
        print(f"   ❗ auto_arima failed for '{family}': {e}\n")
        continue

    # 4i) Fit SARIMAX on the scaled target and scaled exogenous
    print("  Fitting SARIMAX on scaled series with scaled exogenous...")
    try:
        model = SARIMAX(
            df_train_series["y_scaled"],
            exog=exog_train,
            order=order_opt,
            seasonal_order=seasonal_order_opt,
            enforce_stationarity=False,
            enforce_invertibility=False
        )
        sarimax_fit = model.fit(disp=False)
    except Exception as e:
        print(f"   ❗ SARIMAX fit error for '{family}': {e}\n")
        continue

    # 4j) Save the fitted model to Model3/
    safe_name  = family.replace(" ", "_").replace("/", "_").replace("\\", "_")
    model_file = f"sarimax_family_{safe_name}.pkl"
    model_path = os.path.join(MODEL_DIR, model_file)
    try:
        sarimax_fit.save(model_path)
        print(f"   → Saved model to {model_path}")
    except Exception as e:
        print(f"   ❗ Could not save model for '{family}': {e}")

    # 5) Compute hold-out metrics (if applicable)
    if df_valid_holdout is not None:
        print("  Computing hold-out metrics:")
        # Forecast on scaled hold-out exogenous
        # NOTE: convert Series to np.array before reshape
        pred_scaled_valid = sarimax_fit.get_forecast(
            steps=N_VALID,
            exog=exog_valid.values.reshape(-1, 1)
        ).predicted_mean

        # Invert scaling and log-transform to get predictions on original sales scale
        pred_log_valid = scaler_y.inverse_transform(pred_scaled_valid.values.reshape(-1, 1)).ravel()
        pred_valid     = np.expm1(pred_log_valid)
        actual_valid   = df_valid_holdout["sales"].values

        rmse_val = np.sqrt(mean_squared_error(actual_valid, pred_valid))
        mae_val  = mean_absolute_error(actual_valid, pred_valid)
        r2_val   = r2_score(actual_valid, pred_valid)
        mape_val = np.mean(np.abs((actual_valid - pred_valid) / actual_valid)) * 100

        print(f"   → RMSE = {rmse_val:.2f}, MAE = {mae_val:.2f}, R² = {r2_val:.3f}, MAPE = {mape_val:.2f}%")
        performance_records.append({
            "family": family,
            "RMSE": rmse_val,
            "MAE": mae_val,
            "R2": r2_val,
            "MAPE": mape_val
        })

    # 6) Forecast on test set for this family
    df_test_sub = df_test_all[df_test_all["family"] == family].copy()
    if df_test_sub.empty:
        print(f"  No rows for '{family}' in test.csv. Skipping forecast.\n")
        continue

    df_test_sub["date"] = pd.to_datetime(df_test_sub["date"])
    agg_exog_test = (
        df_test_sub.groupby("date")[["onpromotion"]]
                   .sum()
                   .rename(columns={"onpromotion": "onpromo"})
    )
    agg_exog_test.index = pd.DatetimeIndex(agg_exog_test.index).to_period(FREQ)
    agg_exog_test = agg_exog_test.asfreq(FREQ, fill_value=0)

    exog_test_raw   = agg_exog_test["onpromo"].values.reshape(-1, 1)
    exog_test_scaled = scaler_x.transform(exog_test_raw).ravel()

    h = len(agg_exog_test)
    print(f"  Forecasting {h} future points for '{family}' on test set...")
    try:
        pred_scaled_test = sarimax_fit.get_forecast(
            steps=h,
            exog=exog_test_scaled.reshape(-1, 1)
        ).predicted_mean

        pred_log_test   = scaler_y.inverse_transform(pred_scaled_test.values.reshape(-1, 1)).ravel()
        pred_sales_test = np.expm1(pred_log_test)
    except Exception as e:
        print(f"   ❗ Forecast error for '{family}': {e}\n")
        continue

    # Build date-level forecast DataFrame
    df_forecast_dates = pd.DataFrame({
        "date": agg_exog_test.index.to_timestamp(),
        "predicted_sales": pred_sales_test
    })

    # Broadcast forecasts to each store in the test subset
    df_test_sub = df_test_sub.merge(
        df_forecast_dates,
        left_on="date",
        right_on="date",
        how="left"
    )

    df_forecast_f = pd.DataFrame({
        "id": df_test_sub["id"].values,
        "date": df_test_sub["date"].values,
        "store_nbr": df_test_sub["store_nbr"].values,
        "family": family,
        "predicted_sales": df_test_sub["predicted_sales"].values
    })

    forecast_records.append(df_forecast_f)
    print(f"   → Done forecasting for '{family}'.")

# ────────────────────────────────────────────────────────────────────────────────
print("\n" + "=" * 60)
print("All families processed.\n")

# 5) Save performance metrics
if performance_records:
    perf_df = pd.DataFrame(performance_records)
    perf_df.to_csv(PERF_CSV, index=False)
    print(f"Hold-out performance metrics saved to {PERF_CSV}")
    display(perf_df)
else:
    print("No hold-out metrics were generated (N_VALID might be 0).")

# 6) Save all forecasts
if forecast_records:
    all_forecasts_df = pd.concat(forecast_records, axis=0, ignore_index=True)
    all_forecasts_df = all_forecasts_df.sort_values(["family", "date", "store_nbr"]).reset_index(drop=True)
    all_forecasts_df.to_csv(FORECAST_CSV, index=False)
    print(f"All forecasts saved to {FORECAST_CSV}")
    display(all_forecasts_df.head(20))
else:
    print("No forecasts generated (check test.csv).")
# Out:
# ============================================================
# Processing family = 'BEAUTY'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.04183
#   p-value:            0.26854
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (3, 1, 1), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_BEAUTY.pkl
#   Computing hold-out metrics:
#    → RMSE = 45.70, MAE = 38.72, R² = 0.658, MAPE = 10.22%
#   Forecasting 16 future points for 'BEAUTY' on test set...
#    → Done forecasting for 'BEAUTY'.
#
# ============================================================
# Processing family = 'BEVERAGES'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.36523
#   p-value:            0.15179
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_BEVERAGES.pkl
#   Computing hold-out metrics:
#    → RMSE = 21451.06, MAE = 18345.71, R² = 0.371, MAPE = 9.75%
#   Forecasting 16 future points for 'BEVERAGES' on test set...
#    → Done forecasting for 'BEVERAGES'.
#
# ============================================================
# Processing family = 'BREAD/BAKERY'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -1.99023
#   p-value:            0.29087
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 3), seasonal_order = (2, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_BREAD_BAKERY.pkl
#   Computing hold-out metrics:
#    → RMSE = 3335.00, MAE = 2607.95, R² = 0.151, MAPE = 8.97%
#   Forecasting 16 future points for 'BREAD/BAKERY' on test set...
#    → Done forecasting for 'BREAD/BAKERY'.
#
# ============================================================
# Processing family = 'CLEANING'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.93611
#   p-value:            0.04131
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 0), seasonal_order = (2, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_CLEANING.pkl
#   Computing hold-out metrics:
#    → RMSE = 37396.29, MAE = 34481.58, R² = -9.429, MAPE = 58.80%
#   Forecasting 16 future points for 'CLEANING' on test set...
#    → Done forecasting for 'CLEANING'.
#
# ============================================================
# Processing family = 'DAIRY'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -1.92960
#   p-value:            0.31827
#   Critical Value (1%): -3.43432
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56770
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_DAIRY.pkl
#   Computing hold-out metrics:
#    → RMSE = 4771.20, MAE = 3597.52, R² = 0.446, MAPE = 8.09%
#   Forecasting 16 future points for 'DAIRY' on test set...
#    → Done forecasting for 'DAIRY'.
#
# ============================================================
# Processing family = 'DELI'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.31510
#   p-value:            0.16714
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 3), seasonal_order = (2, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_DELI.pkl
#   Computing hold-out metrics:
#    → RMSE = 1814.39, MAE = 1328.49, R² = 0.485, MAPE = 8.51%
#   Forecasting 16 future points for 'DELI' on test set...
#    → Done forecasting for 'DELI'.
#
# ============================================================
# Processing family = 'EGGS'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.22617
#   p-value:            0.19688
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 5), seasonal_order = (0, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_EGGS.pkl
#   Computing hold-out metrics:
#    → RMSE = 1686.40, MAE = 1443.74, R² = 0.412, MAPE = 13.71%
#   Forecasting 16 future points for 'EGGS' on test set...
#    → Done forecasting for 'EGGS'.
#
# ============================================================
# Processing family = 'FROZEN FOODS'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -6.60001
#   p-value:            0.00000
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (3, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_FROZEN_FOODS.pkl
#   Computing hold-out metrics:
#    → RMSE = 747.18, MAE = 555.30, R² = 0.802, MAPE = 7.75%
#   Forecasting 16 future points for 'FROZEN FOODS' on test set...
#    → Done forecasting for 'FROZEN FOODS'.
#
# ============================================================
# Processing family = 'GROCERY I'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -3.35610
#   p-value:            0.01255
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 0), seasonal_order = (2, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_GROCERY_I.pkl
#   Computing hold-out metrics:
#    → RMSE = 26215.15, MAE = 20713.22, R² = 0.334, MAPE = 8.40%
#   Forecasting 16 future points for 'GROCERY I' on test set...
#    → Done forecasting for 'GROCERY I'.
#
# ============================================================
# Processing family = 'GROCERY II'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -5.57345
#   p-value:            0.00000
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_GROCERY_II.pkl
#   Computing hold-out metrics:
#    → RMSE = 496.91, MAE = 443.96, R² = -5.065, MAPE = 30.03%
#   Forecasting 16 future points for 'GROCERY II' on test set...
#    → Done forecasting for 'GROCERY II'.
#
# ============================================================
# Processing family = 'LAWN AND GARDEN'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -1.42903
#   p-value:            0.56828
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_LAWN_AND_GARDEN.pkl
#   Computing hold-out metrics:
#    → RMSE = 90.11, MAE = 67.93, R² = 0.689, MAPE = 7.90%
#   Forecasting 16 future points for 'LAWN AND GARDEN' on test set...
#    → Done forecasting for 'LAWN AND GARDEN'.
#
# ============================================================
# Processing family = 'LINGERIE'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -4.68208
#   p-value:            0.00009
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_LINGERIE.pkl
#   Computing hold-out metrics:
#    → RMSE = 51.15, MAE = 39.09, R² = -0.200, MAPE = 8.86%
#   Forecasting 16 future points for 'LINGERIE' on test set...
#    → Done forecasting for 'LINGERIE'.
#
# ============================================================
# Processing family = 'LIQUOR,WINE,BEER'
#   Removed 0 zero-sales rows → 1506 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -6.60779
#   p-value:            0.00000
#   Critical Value (1%): -3.43482
#   Critical Value (5%): -2.86351
#   Critical Value (10%): -2.56782
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (2, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_LIQUOR,WINE,BEER.pkl
#   Computing hold-out metrics:
#    → RMSE = 1897.87, MAE = 1618.02, R² = 0.492, MAPE = 34.20%
#   Forecasting 16 future points for 'LIQUOR,WINE,BEER' on test set...
#    → Done forecasting for 'LIQUOR,WINE,BEER'.
#
# ============================================================
# Processing family = 'MEATS'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -5.75375
#   p-value:            0.00000
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (4, 1, 1), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_MEATS.pkl
#   Computing hold-out metrics:
#    → RMSE = 1698.53, MAE = 1419.22, R² = 0.803, MAPE = 7.01%
#   Forecasting 16 future points for 'MEATS' on test set...
#    → Done forecasting for 'MEATS'.
#
# ============================================================
# Processing family = 'PERSONAL CARE'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.95632
#   p-value:            0.03918
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 0), seasonal_order = (2, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_PERSONAL_CARE.pkl
#   Computing hold-out metrics:
#    → RMSE = 9766.44, MAE = 8975.15, R² = -7.171, MAPE = 55.00%
#   Forecasting 16 future points for 'PERSONAL CARE' on test set...
#    → Done forecasting for 'PERSONAL CARE'.
#
# ============================================================
# Processing family = 'POULTRY'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.38846
#   p-value:            0.14502
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (1, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_POULTRY.pkl
#   Computing hold-out metrics:
#    → RMSE = 2226.42, MAE = 1700.54, R² = 0.659, MAPE = 8.49%
#   Forecasting 16 future points for 'POULTRY' on test set...
#    → Done forecasting for 'POULTRY'.
#
# ============================================================
# Processing family = 'PREPARED FOODS'
#   Removed 0 zero-sales rows → 1684 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.80307
#   p-value:            0.05784
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 3), seasonal_order = (0, 0, 0, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_PREPARED_FOODS.pkl
#   Computing hold-out metrics:
#    → RMSE = 393.83, MAE = 319.18, R² = 0.069, MAPE = 6.90%
#   Forecasting 16 future points for 'PREPARED FOODS' on test set...
#    → Done forecasting for 'PREPARED FOODS'.
#
# ============================================================
# Processing family = 'AUTOMOTIVE'
#   Removed 0 zero-sales rows → 1683 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -3.16413
#   p-value:            0.02216
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_AUTOMOTIVE.pkl
#   Computing hold-out metrics:
#    → RMSE = 58.11, MAE = 44.71, R² = 0.498, MAPE = 10.81%
#   Forecasting 16 future points for 'AUTOMOTIVE' on test set...
#    → Done forecasting for 'AUTOMOTIVE'.
#
# ============================================================
# Processing family = 'HARDWARE'
#   Removed 0 zero-sales rows → 1681 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -4.75880
#   p-value:            0.00007
#   Critical Value (1%): -3.43433
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_HARDWARE.pkl
#   Computing hold-out metrics:
#    → RMSE = 11.52, MAE = 9.67, R² = 0.476, MAPE = 14.06%
#   Forecasting 16 future points for 'HARDWARE' on test set...
#    → Done forecasting for 'HARDWARE'.
#
# ============================================================
# Processing family = 'SEAFOOD'
#   Removed 0 zero-sales rows → 1683 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -4.42557
#   p-value:            0.00027
#   Critical Value (1%): -3.43434
#   Critical Value (5%): -2.86330
#   Critical Value (10%): -2.56771
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_SEAFOOD.pkl
#   Computing hold-out metrics:
#    → RMSE = 108.43, MAE = 86.80, R² = 0.612, MAPE = 8.39%
#   Forecasting 16 future points for 'SEAFOOD' on test set...
#    → Done forecasting for 'SEAFOOD'.
#
# ============================================================
# Processing family = 'HOME APPLIANCES'
#   Removed 0 zero-sales rows → 1655 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -4.63817
#   p-value:            0.00011
#   Critical Value (1%): -3.43440
#   Critical Value (5%): -2.86333
#   Critical Value (10%): -2.56772
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_HOME_APPLIANCES.pkl
#   Computing hold-out metrics:
#    → RMSE = 6.35, MAE = 5.02, R² = -0.440, MAPE = 117.01%
#   Forecasting 16 future points for 'HOME APPLIANCES' on test set...
#    → Done forecasting for 'HOME APPLIANCES'.
#
# ============================================================
# Processing family = 'PRODUCE'
#   Removed 0 zero-sales rows → 1610 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.96810
#   p-value:            0.03798
#   Critical Value (1%): -3.43451
#   Critical Value (5%): -2.86338
#   Critical Value (10%): -2.56775
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 0), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_PRODUCE.pkl
#   Computing hold-out metrics:
#    → RMSE = 16450.22, MAE = 13320.95, R² = 0.277, MAPE = 10.86%
#   Forecasting 16 future points for 'PRODUCE' on test set...
#    → Done forecasting for 'PRODUCE'.
#
# ============================================================
# Processing family = 'CELEBRATION'
#   Removed 0 zero-sales rows → 1019 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -4.67669
#   p-value:            0.00009
#   Critical Value (1%): -3.43701
#   Critical Value (5%): -2.86448
#   Critical Value (10%): -2.56834
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_CELEBRATION.pkl
#   Computing hold-out metrics:
#    → RMSE = 72.76, MAE = 62.43, R² = 0.731, MAPE = 9.20%
#   Forecasting 16 future points for 'CELEBRATION' on test set...
#    → Done forecasting for 'CELEBRATION'.
#
# ============================================================
# Processing family = 'HOME AND KITCHEN I'
#   Removed 0 zero-sales rows → 1170 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -4.53146
#   p-value:            0.00017
#   Critical Value (1%): -3.43613
#   Critical Value (5%): -2.86409
#   Critical Value (10%): -2.56813
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (2, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_HOME_AND_KITCHEN_I.pkl
#   Computing hold-out metrics:
#    → RMSE = 594.16, MAE = 559.49, R² = -4.556, MAPE = 31.79%
#   Forecasting 16 future points for 'HOME AND KITCHEN I' on test set...
#    → Done forecasting for 'HOME AND KITCHEN I'.
#
# ============================================================
# Processing family = 'HOME AND KITCHEN II'
#   Removed 0 zero-sales rows → 1170 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -3.56653
#   p-value:            0.00643
#   Critical Value (1%): -3.43613
#   Critical Value (5%): -2.86409
#   Critical Value (10%): -2.56813
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_HOME_AND_KITCHEN_II.pkl
#   Computing hold-out metrics:
#    → RMSE = 346.92, MAE = 276.22, R² = -0.774, MAPE = 18.24%
#   Forecasting 16 future points for 'HOME AND KITCHEN II' on test set...
#    → Done forecasting for 'HOME AND KITCHEN II'.
#
# ============================================================
# Processing family = 'HOME CARE'
#   Removed 0 zero-sales rows → 1047 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -5.91907
#   p-value:            0.00000
#   Critical Value (1%): -3.43683
#   Critical Value (5%): -2.86440
#   Critical Value (10%): -2.56829
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_HOME_CARE.pkl
#   Computing hold-out metrics:
#    → RMSE = 1949.84, MAE = 1470.41, R² = 0.448, MAPE = 9.57%
#   Forecasting 16 future points for 'HOME CARE' on test set...
#    → Done forecasting for 'HOME CARE'.
#
# ============================================================
# Processing family = 'MAGAZINES'
#   Removed 0 zero-sales rows → 1080 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -2.77842
#   p-value:            0.06142
#   Critical Value (1%): -3.43663
#   Critical Value (5%): -2.86431
#   Critical Value (10%): -2.56825
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (2, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_MAGAZINES.pkl
#   Computing hold-out metrics:
#    → RMSE = 112.98, MAE = 103.58, R² = -0.201, MAPE = 27.30%
#   Forecasting 16 future points for 'MAGAZINES' on test set...
#    → Done forecasting for 'MAGAZINES'.
#
# ============================================================
# Processing family = 'PET SUPPLIES'
#   Removed 0 zero-sales rows → 1026 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -1.78499
#   p-value:            0.38794
#   Critical Value (1%): -3.43697
#   Critical Value (5%): -2.86446
#   Critical Value (10%): -2.56833
#   → The series is NOT stationary (fail to reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_PET_SUPPLIES.pkl
#   Computing hold-out metrics:
#    → RMSE = 54.71, MAE = 39.92, R² = 0.638, MAPE = 8.32%
#   Forecasting 16 future points for 'PET SUPPLIES' on test set...
#    → Done forecasting for 'PET SUPPLIES'.
#
# ============================================================
# Processing family = 'PLAYERS AND ELECTRONICS'
#   Removed 0 zero-sales rows → 1019 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -3.78315
#   p-value:            0.00308
#   Critical Value (1%): -3.43702
#   Critical Value (5%): -2.86448
#   Critical Value (10%): -2.56834
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (1, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_PLAYERS_AND_ELECTRONICS.pkl
#   Computing hold-out metrics:
#    → RMSE = 52.41, MAE = 46.75, R² = 0.761, MAPE = 7.50%
#   Forecasting 16 future points for 'PLAYERS AND ELECTRONICS' on test set...
#    → Done forecasting for 'PLAYERS AND ELECTRONICS'.
#
# ============================================================
# Processing family = 'LADIESWEAR'
#   Removed 0 zero-sales rows → 1016 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -5.98905
#   p-value:            0.00000
#   Critical Value (1%): -3.43704
#   Critical Value (5%): -2.86449
#   Critical Value (10%): -2.56834
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (4, 1, 1), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_LADIESWEAR.pkl
#   Computing hold-out metrics:
#    → RMSE = 119.99, MAE = 98.35, R² = 0.527, MAPE = 20.40%
#   Forecasting 16 future points for 'LADIESWEAR' on test set...
#    → Done forecasting for 'LADIESWEAR'.
#
# ============================================================
# Processing family = 'SCHOOL AND OFFICE SUPPLIES'
#   Removed 0 zero-sales rows → 1016 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -3.87416
#   p-value:            0.00223
#   Critical Value (1%): -3.43699
#   Critical Value (5%): -2.86447
#   Critical Value (10%): -2.56833
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (3, 1, 0), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_SCHOOL_AND_OFFICE_SUPPLIES.pkl
#   Computing hold-out metrics:
#    → RMSE = 7414.83, MAE = 5392.40, R² = -87.894, MAPE = 171.32%
#   Forecasting 16 future points for 'SCHOOL AND OFFICE SUPPLIES' on test set...
#    → Done forecasting for 'SCHOOL AND OFFICE SUPPLIES'.
#
# ============================================================
# Processing family = 'BABY CARE'
#   Removed 0 zero-sales rows → 891 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -3.99689
#   p-value:            0.00143
#   Critical Value (1%): -3.43795
#   Critical Value (5%): -2.86489
#   Critical Value (10%): -2.56856
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 3), seasonal_order = (1, 0, 2, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_BABY_CARE.pkl
#   Computing hold-out metrics:
#    → RMSE = 4.16, MAE = 3.70, R² = -0.115, MAPE = 60.63%
#   Forecasting 16 future points for 'BABY CARE' on test set...
#    → Done forecasting for 'BABY CARE'.
#
# ============================================================
# Processing family = 'BOOKS'
#   Removed 0 zero-sales rows → 287 remaining
#   Held out last 14 days for validation.
#   Running ADF test on training 'sales' series:
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   ADF Statistic (sales): -3.96532
#   p-value:            0.00160
#   Critical Value (1%): -3.45585
#   Critical Value (5%): -2.87276
#   Critical Value (10%): -2.57275
#   → The series IS stationary (reject H₀).
#   ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─  ─
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (2, 1, 1), seasonal_order = (1, 0, 0, 7)
#   Fitting SARIMAX on scaled series with scaled exogenous...
#    → Saved model to Model3\sarimax_family_BOOKS.pkl
#   Computing hold-out metrics:
#    → RMSE = 0.91, MAE = 0.76, R² = -0.226, MAPE = 63.98%
#   Forecasting 16 future points for 'BOOKS' on test set...
#    → Done forecasting for 'BOOKS'.
#
# ============================================================
# All families processed.
#
# Hold-out performance metrics saved to Performance\performance_all_families.csv
#                         family          RMSE           MAE         R2  \
# 0                       BEAUTY     45.701553     38.717910   0.657927
# 1                    BEVERAGES  21451.056731  18345.709094   0.371192
# 2                 BREAD/BAKERY   3334.999966   2607.949527   0.151131
# 3                     CLEANING  37396.294632  34481.576976  -9.429157
# 4                        DAIRY   4771.198453   3597.523202   0.445720
# 5                         DELI   1814.385591   1328.488568   0.485269
# 6                         EGGS   1686.402971   1443.740985   0.412380
# 7                 FROZEN FOODS    747.177253    555.304148   0.801912
# 8                    GROCERY I  26215.152853  20713.221745   0.334263
# 9                   GROCERY II    496.905122    443.960195  -5.065413
# 10             LAWN AND GARDEN     90.114057     67.933376   0.688967
# 11                    LINGERIE     51.150097     39.092984  -0.199869
# 12            LIQUOR,WINE,BEER   1897.865978   1618.020501   0.492224
# 13                       MEATS   1698.531510   1419.217407   0.803168
# 14               PERSONAL CARE   9766.444533   8975.150237  -7.170538
# 15                     POULTRY   2226.420189   1700.540696   0.658543
# 16              PREPARED FOODS    393.831792    319.176089   0.068704
# 17                  AUTOMOTIVE     58.108774     44.713705   0.497971
# 18                    HARDWARE     11.524816      9.671103   0.475828
# 19                     SEAFOOD    108.431119     86.799315   0.611649
# 20             HOME APPLIANCES      6.353139      5.023182  -0.440201
# 21                     PRODUCE  16450.220882  13320.945300   0.277187
# 22                 CELEBRATION     72.757193     62.429942   0.731390
# 23          HOME AND KITCHEN I    594.160199    559.491975  -4.555986
# 24         HOME AND KITCHEN II    346.915714    276.219582  -0.773574
# 25                   HOME CARE   1949.835727   1470.414649   0.448230
# 26                   MAGAZINES    112.984908    103.575727  -0.200598
# 27                PET SUPPLIES     54.710529     39.915697   0.638049
# 28     PLAYERS AND ELECTRONICS     52.411964     46.753454   0.761229
# 29                  LADIESWEAR    119.990143     98.353966   0.527068
# 30  SCHOOL AND OFFICE SUPPLIES   7414.827576   5392.404394 -87.894159
# 31                   BABY CARE      4.159895      3.697313  -0.115333
# 32                       BOOKS      0.912265      0.764999  -0.226440
#
#           MAPE
# 0    10.219163
# 1     9.752256
# 2     8.967921
# 3    58.803948
# 4     8.092465
# 5     8.509359
# 6    13.708516
# 7     7.752965
# 8     8.403149
# 9    30.032185
# 10    7.901264
# 11    8.862165
# 12   34.201756
# 13    7.011424
# 14   54.998273
# 15    8.488827
# 16    6.900909
# 17   10.810161
# 18   14.056094
# 19    8.389678
# 20  117.007229
# 21   10.864555
# 22    9.199473
# 23   31.790348
# 24   18.236396
# 25    9.566226
# 26   27.296723
# 27    8.321226
# 28    7.501339
# 29   20.399201
# 30  171.316544
# 31   60.632834
# 32   63.980469
# All forecasts saved to forecasts_all_families.csv
#          id       date  store_nbr      family  predicted_sales
# 0   3000888 2017-08-16          1  AUTOMOTIVE       319.715565
# 1   3001251 2017-08-16          2  AUTOMOTIVE       319.715565
# 2   3001614 2017-08-16          3  AUTOMOTIVE       319.715565
# 3   3001977 2017-08-16          4  AUTOMOTIVE       319.715565
# 4   3002340 2017-08-16          5  AUTOMOTIVE       319.715565
# 5   3002538 2017-08-16          6  AUTOMOTIVE       319.715565
# 6   3002571 2017-08-16          7  AUTOMOTIVE       319.715565
# 7   3002604 2017-08-16          8  AUTOMOTIVE       319.715565
# 8   3002637 2017-08-16          9  AUTOMOTIVE       319.715565
# 9   3000921 2017-08-16         10  AUTOMOTIVE       319.715565
# 10  3000954 2017-08-16         11  AUTOMOTIVE       319.715565
# 11  3000987 2017-08-16         12  AUTOMOTIVE       319.715565
# 12  3001020 2017-08-16         13  AUTOMOTIVE       319.715565
# 13  3001053 2017-08-16         14  AUTOMOTIVE       319.715565
# 14  3001086 2017-08-16         15  AUTOMOTIVE       319.715565
# 15  3001119 2017-08-16         16  AUTOMOTIVE       319.715565
# 16  3001152 2017-08-16         17  AUTOMOTIVE       319.715565
# 17  3001185 2017-08-16         18  AUTOMOTIVE       319.715565
# 18  3001218 2017-08-16         19  AUTOMOTIVE       319.715565
# 19  3001284 2017-08-16         20  AUTOMOTIVE       319.715565
