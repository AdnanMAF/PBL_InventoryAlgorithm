# %% [markdown]
# # SARIMAX Forecasting: Train on `train.csv`, Forecast on `test.csv`
#
# **Workflow**:
# 1. Import libraries.
# 2. Configure paths & parameters.
# 3. Read `train.csv` (with `sales`) and `test.csv` (future dates, no `sales`).
# 4. Loop over each product family:
#    - Aggregate daily `sales` & `onpromotion` from `train.csv`.
#    - (Optional) Hold out last `N_VALID` days of `train.csv` for sanity‐check metrics.
#    - Fit SARIMAX on full `train.csv` series (log1p‐transformed), selected via `auto_arima`.
#    - Save model to `models2/`.
#    - Forecast exactly on the dates present in `test.csv` (using its `onpromotion`).
# 5. (Optional) Compute RMSE/MAE/R² on held‐out portion of `train.csv` and save to `performance_results2.csv`.
# 6. Save all forecasts (for `test.csv`) into `forecasts2.csv`.

# %%
import os
import warnings

import numpy as np
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX, SARIMAXResults
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from pmdarima import auto_arima

# Suppress warnings (optional)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. CONFIGURABLE PARAMETERS

# %%
# (A) Input file paths (adjust if needed)
TRAIN_CSV = "../Data/DM/train.csv"   # Must contain columns: [id, date, store_nbr, family, sales, onpromotion]
TEST_CSV  = "../Data/DM/test.csv"    # Must contain columns: [id, date, store_nbr, family, onpromotion]

# (B) Output directories / filenames
ALL_MODELS_DIR = os.path.join("Models","models2")
os.makedirs(ALL_MODELS_DIR, exist_ok=True)

PERF_DIR    = "Performance"
FORE_DIR    = "Forecasts"
os.makedirs(PERF_DIR, exist_ok=True)
os.makedirs(FORE_DIR, exist_ok=True)

PERF_CSV     = "performance_results2.csv"  # hold-out metrics file (if N_VALID > 0)
FORECAST_CSV = "forecasts2.csv"            # final forecast on test.csv dates

# (C) Hold-out for sanity-check on train.csv
#     If you want to skip hold-out, set N_VALID = 0
N_VALID = 14

# (D) Time-series frequency
#     'D' = daily, 'W' = weekly, 'M' = monthly, etc.
FREQ = "D"

# (E) auto_arima arguments (alter if your data has different seasonality)
AUTO_ARIMA_ARGS = {
    "seasonal": True,       # assume weekly seasonality
    "m": 7,                 # 7 days → weekly cycle
    "start_p": 0, "start_q": 0, "max_p": 5, "max_q": 5,
    "start_P": 0, "start_Q": 0, "max_P": 2, "max_Q": 2,
    "d": None, "D": None,
    "trace": False,
    "error_action": "ignore",
    "suppress_warnings": True,
    "stepwise": True,
    "information_criterion": "aic"
}

# %% [markdown]
# ## 2. READ TRAIN.CSV & TEST.CSV

# %%
print("Loading train.csv and test.csv...")

# A) Load train.csv (with 'sales' and 'onpromotion')
df_train_all = pd.read_csv(TRAIN_CSV, parse_dates=["date"])
#   Expect columns: [id, date, store_nbr, family, sales, onpromotion]

# B) Load test.csv (only onpromotion; no 'sales')
df_test_all = pd.read_csv(TEST_CSV, parse_dates=["date"])
#   Expect columns: [id, date, store_nbr, family, onpromotion]

print(f"→ train.csv: {df_train_all.shape[0]} rows")
print(f"→ test.csv : {df_test_all.shape[0]} rows\n")

# Extract unique product families from train.csv
unique_families = df_train_all["family"].unique()
print(f"Found {len(unique_families)} unique families.\n")
# Out:
# Loading train.csv and test.csv...
# → train.csv: 3000888 rows
# → test.csv : 28512 rows
#
# Found 33 unique families.

# %% [markdown]
# ## 3. LOOP THROUGH EACH FAMILY → TRAIN on train.csv, SAVE MODEL, FORECAST test.csv

# %%
performance_records = []
forecast_records    = []

for family in unique_families:
    print("=======================================================")
    print(f"Processing family = {family}")

    # 1) Filter train.csv for this family (ALL stores together), then aggregate
    df_f = df_train_all[df_train_all["family"] == family].copy()
    if df_f.empty:
        print(f"  No rows for family '{family}' in train.csv. Skipping.\n")
        continue

    # Aggregate sales & onpromotion by date (summing across all stores)
    df_f_agg = (
        df_f
        .groupby("date")[["sales", "onpromotion"]]
        .sum()
        .rename(columns={"onpromotion": "onpromo"})
        .sort_index()
    )

    # Convert to daily PeriodIndex and fill missing dates with 0
    df_f_agg.index = pd.DatetimeIndex(df_f_agg.index).to_period(FREQ)
    df_f_agg = df_f_agg.asfreq(FREQ)
    df_f_agg["sales"]   = df_f_agg["sales"].fillna(0).astype(float)
    df_f_agg["onpromo"] = df_f_agg["onpromo"].fillna(0).astype(float)

    # If not enough points to hold out, skip
    if len(df_f_agg) < (N_VALID + 1):
        print(f"  Only {len(df_f_agg)} points for {family} (< N_VALID+1). Skipping.\n")
        continue

    # 2) (Optional) Hold out last N_VALID days for sanity-check
    if N_VALID > 0:
        df_valid_holdout = df_f_agg.iloc[-N_VALID:]
        df_train_series  = df_f_agg.iloc[: -N_VALID]
        print(f"  Held out {N_VALID} days from train for validation.")
    else:
        df_valid_holdout = None
        df_train_series  = df_f_agg

    # 3) Log-transform the aggregated sales
    df_train_series["y_log"] = np.log1p(df_train_series["sales"])

    # 4) Prepare exogenous for the model (only “onpromo”, no store_nbr)
    exog_train = df_train_series["onpromo"]
    exog_valid = df_valid_holdout["onpromo"] if df_valid_holdout is not None else None

    # 5) Auto-arima on log1p‐sales
    print("  Running auto_arima for hyperparameter tuning...")
    try:
        mi = auto_arima(
            df_train_series["y_log"],
            exogenous = exog_train.values.reshape(-1, 1),
            **AUTO_ARIMA_ARGS
        )
        order_opt          = mi.order
        seasonal_order_opt = mi.seasonal_order
        print(f"   → Selected order = {order_opt}, seasonal_order = {seasonal_order_opt}")
    except Exception as e:
        print(f"   ❗ auto_arima failed for {family}: {e}\n")
        continue

    # 6) Fit SARIMAX on the entire (or held-out) log1p‐series, ignoring store_nbr
    print("  Fitting SARIMAX on the training series (aggregated across stores)...")
    try:
        model = SARIMAX(
            df_train_series["y_log"],
            exog = exog_train,
            order = order_opt,
            seasonal_order = seasonal_order_opt,
            enforce_stationarity = False,
            enforce_invertibility = False
        )
        sarimax_fit = model.fit(disp=False)
    except Exception as e:
        print(f"   ❗ SARIMAX fit error for {family}: {e}\n")
        continue

    # 7) Save the model (.pkl) under all_models/—one model per family
    safe_name = family.replace(" ", "_").replace("/", "_").replace("\\", "_")
    model_file = f"sarimax_family_{safe_name}.pkl"
    model_path = os.path.join(ALL_MODELS_DIR, model_file)
    try:
        sarimax_fit.save(model_path)
        print(f"   → Saved model to {model_path}")
    except Exception as e:
        print(f"   ❗ Could not save model for {family}: {e}")

    # 8) (Optional) Evaluate hold-out performance if N_VALID > 0
    if df_valid_holdout is not None:
        print("  Computing hold-out metrics on train hold-out...")
        try:
            pred_log_valid = sarimax_fit.get_forecast(
                steps=N_VALID,
                exog = exog_valid
            ).predicted_mean
            pred_valid = np.expm1(pred_log_valid)
            actual_valid = df_valid_holdout["sales"].values

            rmse_val = np.sqrt(mean_squared_error(actual_valid, pred_valid))
            mae_val  = mean_absolute_error(actual_valid, pred_valid)
            r2_val   = r2_score(actual_valid, pred_valid)
            print(f"   → Hold-out metrics: RMSE={rmse_val:.2f}, MAE={mae_val:.2f}, R²={r2_val:.3f}")
            performance_records.append({
                "family": family,
                "RMSE": rmse_val,
                "MAE": mae_val,
                "R2": r2_val
            })
        except Exception as e:
            print(f"   ❗ Hold-out forecasting error for {family}: {e}")

    # 9) Forecast on test.csv dates—but first aggregate “onpromotion” by date across all stores
    df_test_sub = df_test_all[df_test_all["family"] == family].copy()
    if df_test_sub.empty:
        print(f"  No rows for {family} in test.csv. Skipping forecast.\n")
        continue

    # Aggregate exogenous (“onpromotion”) by date so we have exactly one row per date
    df_test_sub["date"] = pd.to_datetime(df_test_sub["date"])
    agg_exog = (
        df_test_sub
        .groupby("date")[["onpromotion"]]
        .sum()
        .rename(columns={"onpromotion": "onpromo"})
    )

    # Convert agg_exog.index to PeriodIndex and reindex to daily freq
    agg_exog.index = pd.DatetimeIndex(agg_exog.index).to_period(FREQ)
    agg_exog = agg_exog.asfreq(FREQ, fill_value=0)

    # Forecast “h” points, where h = number of unique dates in agg_exog
    h = len(agg_exog)
    print(f"  Forecasting {h} future points on test.csv for {family}...")
    try:
        pred_log_test = sarimax_fit.get_forecast(
            steps = h,
            exog = agg_exog["onpromo"]
        ).predicted_mean
        pred_sales_test = np.expm1(pred_log_test)
    except Exception as e:
        print(f"   ❗ Forecast error on test for {family}: {e}\n")
        continue

    # 10) Create a date‐level forecast DataFrame and then “broadcast” it back to each store row
    df_forecast_dates = pd.DataFrame({
        "date": agg_exog.index.to_timestamp(),    # e.g. Timestamp("2025-06-01")
        "predicted_sales": pred_sales_test.values
    })

    # Merge these date‐level predictions back onto every row of df_test_sub
    df_test_sub = df_test_sub.merge(
        df_forecast_dates,
        left_on = "date",
        right_on = "date",
        how = "left"
    )

    # Finally, keep store_nbr and id so that each branch gets the same per‐family forecast
    df_forecast_f = pd.DataFrame({
        "id": df_test_sub["id"].values,
        "date": df_test_sub["date"].values,
        "store_nbr": df_test_sub["store_nbr"].values,
        "family": family,
        "predicted_sales": df_test_sub["predicted_sales"].values
    })

    forecast_records.append(df_forecast_f)
    print(f"  → Done forecasting for {family}.\n")

print("=======================================================")
print("All families processed.\n")
# Out:
# =======================================================
# Processing family = AUTOMOTIVE
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_AUTOMOTIVE.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=58.11, MAE=44.71, R²=0.498
#   Forecasting 16 future points on test.csv for AUTOMOTIVE...
#   → Done forecasting for AUTOMOTIVE.
#
# =======================================================
# Processing family = BABY CARE
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (2, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_BABY_CARE.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=4.88, MAE=4.32, R²=-0.536
#   Forecasting 16 future points on test.csv for BABY CARE...
#   → Done forecasting for BABY CARE.
#
# =======================================================
# Processing family = BEAUTY
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 4), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_BEAUTY.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=57.73, MAE=43.60, R²=0.454
#   Forecasting 16 future points on test.csv for BEAUTY...
#   → Done forecasting for BEAUTY.
#
# =======================================================
# Processing family = BEVERAGES
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_BEVERAGES.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=28811.95, MAE=19974.96, R²=-0.134
#   Forecasting 16 future points on test.csv for BEVERAGES...
#   → Done forecasting for BEVERAGES.
#
# =======================================================
# Processing family = BOOKS
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (2, 1, 4), seasonal_order = (0, 0, 0, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_BOOKS.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=0.74, MAE=0.61, R²=-0.025
#   Forecasting 16 future points on test.csv for BOOKS...
#   → Done forecasting for BOOKS.
#
# =======================================================
# Processing family = BREAD/BAKERY
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (0, 0, 2, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_BREAD_BAKERY.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=6943.32, MAE=6243.89, R²=-2.679
#   Forecasting 16 future points on test.csv for BREAD/BAKERY...
#   → Done forecasting for BREAD/BAKERY.
#
# =======================================================
# Processing family = CELEBRATION
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_CELEBRATION.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=90.11, MAE=79.65, R²=0.588
#   Forecasting 16 future points on test.csv for CELEBRATION...
#   → Done forecasting for CELEBRATION.
#
# =======================================================
# Processing family = CLEANING
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 1), seasonal_order = (1, 0, 2, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_CLEANING.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=30990.96, MAE=28762.18, R²=-6.162
#   Forecasting 16 future points on test.csv for CLEANING...
#   → Done forecasting for CLEANING.
#
# =======================================================
# Processing family = DAIRY
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_DAIRY.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=9052.80, MAE=8257.37, R²=-0.995
#   Forecasting 16 future points on test.csv for DAIRY...
#   → Done forecasting for DAIRY.
#
# =======================================================
# Processing family = DELI
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_DELI.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=1780.06, MAE=1504.72, R²=0.505
#   Forecasting 16 future points on test.csv for DELI...
#   → Done forecasting for DELI.
#
# =======================================================
# Processing family = EGGS
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 3), seasonal_order = (2, 0, 2, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_EGGS.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=791.29, MAE=617.53, R²=0.871
#   Forecasting 16 future points on test.csv for EGGS...
#   → Done forecasting for EGGS.
#
# =======================================================
# Processing family = FROZEN FOODS
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (4, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_FROZEN_FOODS.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=736.99, MAE=547.37, R²=0.807
#   Forecasting 16 future points on test.csv for FROZEN FOODS...
#   → Done forecasting for FROZEN FOODS.
#
# =======================================================
# Processing family = GROCERY I
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (4, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_GROCERY_I.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=29489.62, MAE=21981.26, R²=0.158
#   Forecasting 16 future points on test.csv for GROCERY I...
#   → Done forecasting for GROCERY I.
#
# =======================================================
# Processing family = GROCERY II
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_GROCERY_II.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=497.03, MAE=444.11, R²=-5.068
#   Forecasting 16 future points on test.csv for GROCERY II...
#   → Done forecasting for GROCERY II.
#
# =======================================================
# Processing family = HARDWARE
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_HARDWARE.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=11.44, MAE=9.79, R²=0.484
#   Forecasting 16 future points on test.csv for HARDWARE...
#   → Done forecasting for HARDWARE.
#
# =======================================================
# Processing family = HOME AND KITCHEN I
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (0, 0, 0, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_HOME_AND_KITCHEN_I.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=797.22, MAE=737.43, R²=-9.002
#   Forecasting 16 future points on test.csv for HOME AND KITCHEN I...
#   → Done forecasting for HOME AND KITCHEN I.
#
# =======================================================
# Processing family = HOME AND KITCHEN II
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_HOME_AND_KITCHEN_II.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=1229.25, MAE=1075.53, R²=-21.268
#   Forecasting 16 future points on test.csv for HOME AND KITCHEN II...
#   → Done forecasting for HOME AND KITCHEN II.
#
# =======================================================
# Processing family = HOME APPLIANCES
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_HOME_APPLIANCES.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=6.77, MAE=5.50, R²=-0.634
#   Forecasting 16 future points on test.csv for HOME APPLIANCES...
#   → Done forecasting for HOME APPLIANCES.
#
# =======================================================
# Processing family = HOME CARE
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 0), seasonal_order = (0, 0, 0, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_HOME_CARE.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=7541.60, MAE=7286.53, R²=-7.254
#   Forecasting 16 future points on test.csv for HOME CARE...
#   → Done forecasting for HOME CARE.
#
# =======================================================
# Processing family = LADIESWEAR
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (2, 1, 0), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_LADIESWEAR.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=149.97, MAE=130.23, R²=0.261
#   Forecasting 16 future points on test.csv for LADIESWEAR...
#   → Done forecasting for LADIESWEAR.
#
# =======================================================
# Processing family = LAWN AND GARDEN
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_LAWN_AND_GARDEN.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=90.11, MAE=67.93, R²=0.689
#   Forecasting 16 future points on test.csv for LAWN AND GARDEN...
#   → Done forecasting for LAWN AND GARDEN.
#
# =======================================================
# Processing family = LINGERIE
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_LINGERIE.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=52.56, MAE=39.75, R²=-0.267
#   Forecasting 16 future points on test.csv for LINGERIE...
#   → Done forecasting for LINGERIE.
#
# =======================================================
# Processing family = LIQUOR,WINE,BEER
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 0), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_LIQUOR,WINE,BEER.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=5522.61, MAE=4102.49, R²=-3.300
#   Forecasting 16 future points on test.csv for LIQUOR,WINE,BEER...
#   → Done forecasting for LIQUOR,WINE,BEER.
#
# =======================================================
# Processing family = MAGAZINES
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_MAGAZINES.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=124.92, MAE=114.50, R²=-0.468
#   Forecasting 16 future points on test.csv for MAGAZINES...
#   → Done forecasting for MAGAZINES.
#
# =======================================================
# Processing family = MEATS
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (3, 1, 1), seasonal_order = (1, 0, 2, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_MEATS.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=2667.60, MAE=2366.09, R²=0.515
#   Forecasting 16 future points on test.csv for MEATS...
#   → Done forecasting for MEATS.
#
# =======================================================
# Processing family = PERSONAL CARE
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (5, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_PERSONAL_CARE.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=9359.27, MAE=8889.98, R²=-6.503
#   Forecasting 16 future points on test.csv for PERSONAL CARE...
#   → Done forecasting for PERSONAL CARE.
#
# =======================================================
# Processing family = PET SUPPLIES
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (3, 1, 1), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_PET_SUPPLIES.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=72.79, MAE=63.90, R²=0.359
#   Forecasting 16 future points on test.csv for PET SUPPLIES...
#   → Done forecasting for PET SUPPLIES.
#
# =======================================================
# Processing family = PLAYERS AND ELECTRONICS
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (2, 1, 0), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_PLAYERS_AND_ELECTRONICS.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=86.83, MAE=72.40, R²=0.345
#   Forecasting 16 future points on test.csv for PLAYERS AND ELECTRONICS...
#   → Done forecasting for PLAYERS AND ELECTRONICS.
#
# =======================================================
# Processing family = POULTRY
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (1, 0, 2, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_POULTRY.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=2816.86, MAE=2472.96, R²=0.453
#   Forecasting 16 future points on test.csv for POULTRY...
#   → Done forecasting for POULTRY.
#
# =======================================================
# Processing family = PREPARED FOODS
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (1, 1, 1), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_PREPARED_FOODS.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=306.08, MAE=267.37, R²=0.437
#   Forecasting 16 future points on test.csv for PREPARED FOODS...
#   → Done forecasting for PREPARED FOODS.
#
# =======================================================
# Processing family = PRODUCE
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (4, 1, 2), seasonal_order = (1, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_PRODUCE.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=16004.01, MAE=12427.08, R²=0.316
#   Forecasting 16 future points on test.csv for PRODUCE...
#   → Done forecasting for PRODUCE.
#
# =======================================================
# Processing family = SCHOOL AND OFFICE SUPPLIES
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (2, 1, 0), seasonal_order = (2, 0, 1, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_SCHOOL_AND_OFFICE_SUPPLIES.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=3181.41, MAE=2315.62, R²=-15.365
#   Forecasting 16 future points on test.csv for SCHOOL AND OFFICE SUPPLIES...
#   → Done forecasting for SCHOOL AND OFFICE SUPPLIES.
#
# =======================================================
# Processing family = SEAFOOD
#   Held out 14 days from train for validation.
#   Running auto_arima for hyperparameter tuning...
#    → Selected order = (0, 1, 2), seasonal_order = (1, 0, 2, 7)
#   Fitting SARIMAX on the training series (aggregated across stores)...
#    → Saved model to models2\sarimax_family_SEAFOOD.pkl
#   Computing hold-out metrics on train hold-out...
#    → Hold-out metrics: RMSE=111.52, MAE=88.49, R²=0.589
#   Forecasting 16 future points on test.csv for SEAFOOD...
#   → Done forecasting for SEAFOOD.
#
# =======================================================
# All families processed.

# %% [markdown]
# ## 4a. SAVE HOLD-OUT PERFORMANCE METRICS TO CSV

# %%
if N_VALID > 0:
    perf_df = pd.DataFrame(performance_records)
    perf_df.to_csv(PERF_CSV, index=False)
    print(f"Hold-out performance metrics saved to {PERF_CSV}")
    display(perf_df)
else:
    print("N_VALID = 0 → Skipping hold-out metric computation.")
# Out:
# Hold-out performance metrics saved to performance_results2.csv
#                         family          RMSE           MAE         R2
# 0                   AUTOMOTIVE     58.105265     44.713942   0.498031
# 1                    BABY CARE      4.881954      4.315050  -0.536127
# 2                       BEAUTY     57.734682     43.596750   0.454078
# 3                    BEVERAGES  28811.946487  19974.961178  -0.134400
# 4                        BOOKS      0.737549      0.612317  -0.025192
# 5                 BREAD/BAKERY   6943.318651   6243.887310  -2.679452
# 6                  CELEBRATION     90.108367     79.652861   0.587997
# 7                     CLEANING  30990.956779  28762.176086  -6.162457
# 8                        DAIRY   9052.795142   8257.368720  -0.995446
# 9                         DELI   1780.059504   1504.723412   0.504561
# 10                        EGGS    791.293508    617.534798   0.870625
# 11                FROZEN FOODS    736.991283    547.374954   0.807276
# 12                   GROCERY I  29489.620891  21981.263968   0.157565
# 13                  GROCERY II    497.027360    444.106791  -5.068398
# 14                    HARDWARE     11.438799      9.791676   0.483624
# 15          HOME AND KITCHEN I    797.216812    737.430573  -9.002463
# 16         HOME AND KITCHEN II   1229.247812   1075.527439 -21.267947
# 17             HOME APPLIANCES      6.766441      5.501213  -0.633680
# 18                   HOME CARE   7541.597341   7286.527676  -7.254468
# 19                  LADIESWEAR    149.973395    130.227829   0.261184
# 20             LAWN AND GARDEN     90.109786     67.925107   0.688996
# 21                    LINGERIE     52.564696     39.753971  -0.267153
# 22            LIQUOR,WINE,BEER   5522.611008   4102.494353  -3.299623
# 23                   MAGAZINES    124.922919    114.503450  -0.467712
# 24                       MEATS   2667.597428   2366.089885   0.514501
# 25               PERSONAL CARE   9359.273832   8889.983414  -6.503467
# 26                PET SUPPLIES     72.792388     63.900215   0.359263
# 27     PLAYERS AND ELECTRONICS     86.833512     72.400455   0.344616
# 28                     POULTRY   2816.858864   2472.963803   0.453423
# 29              PREPARED FOODS    306.080683    267.370680   0.437480
# 30                     PRODUCE  16004.008436  12427.084690   0.315868
# 31  SCHOOL AND OFFICE SUPPLIES   3181.414976   2315.623866 -15.364840
# 32                     SEAFOOD    111.519001     88.487302   0.589216

# %% [markdown]
# ## 4b. SAVE ALL FORECASTS (test.csv predictions) TO CSV

# %%
if forecast_records:
    all_forecasts_df = pd.concat(forecast_records, axis=0, ignore_index=True)
    # Optional: sort by 'id' or by ['family','date']
    all_forecasts_df = all_forecasts_df.sort_values("id").reset_index(drop=True)

    all_forecasts_df.to_csv(FORECAST_CSV, index=False)
    print(f"All forecasts saved to {FORECAST_CSV}")
    display(all_forecasts_df.head(20))
else:
    print("No forecasts generated (check if test.csv had matching families).")
# Out:
# All forecasts saved to forecasts2.csv
#          id       date  store_nbr               family  predicted_sales
# 0   3000888 2017-08-16          1           AUTOMOTIVE       319.731174
# 1   3000889 2017-08-16          1            BABY CARE        12.459296
# 2   3000890 2017-08-16          1               BEAUTY       585.071055
# 3   3000891 2017-08-16          1            BEVERAGES    217954.216139
# 4   3000892 2017-08-16          1                BOOKS         0.460009
# 5   3000893 2017-08-16          1         BREAD/BAKERY     35011.358832
# 6   3000894 2017-08-16          1          CELEBRATION       673.187521
# 7   3000895 2017-08-16          1             CLEANING    107843.269843
# 8   3000896 2017-08-16          1                DAIRY     57912.902679
# 9   3000897 2017-08-16          1                 DELI     16790.988552
# 10  3000898 2017-08-16          1                 EGGS      8791.432084
# 11  3000899 2017-08-16          1         FROZEN FOODS      6262.144575
# 12  3000900 2017-08-16          1            GROCERY I    421157.552447
# 13  3000901 2017-08-16          1           GROCERY II      1750.052972
# 14  3000902 2017-08-16          1             HARDWARE        76.524914
# 15  3000903 2017-08-16          1   HOME AND KITCHEN I      1463.923550
# 16  3000904 2017-08-16          1  HOME AND KITCHEN II     32532.147203
# 17  3000905 2017-08-16          1      HOME APPLIANCES        13.070935
# 18  3000906 2017-08-16          1            HOME CARE     83337.321301
# 19  3000907 2017-08-16          1           LADIESWEAR       590.197353
